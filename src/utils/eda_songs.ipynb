# %% [markdown]
# # Exploratory Data Analysis
#
# 1. Who is the most productive (popular) artist in the dataset?
# 2. How many songs name occur more than once? Who are the artists?
# 3. Illustrate the distribution of artists and the number of unique songs.
# 4. Prepare counts of artists top songs for each year.
# 5. Number of artists only appearing once.
# 6. Number of unique artists

# %%
import scipy
import vapeplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read lyrics csv to pd.dataframe
df = pd.read_csv("../../data/preprocessed_songdata.csv")

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face And it...
# 1  Take it easy with me, please Touch me gently l...
# 2  I'll never know why I had to go Why I had to p...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %% [markdown]
# ## Most productive artists

# %%
artist_appearance_counts = df.artist.value_counts()
artist_appearance_counts_norm = df.artist.value_counts(normalize=True)

artist_appearance_counts
# Out:
# Donna Summer                                    191
# Gordon Lightfoot                                189
# George Strait                                   188
# Bob Dylan                                       188
# Loretta Lynn                                    187
# Cher                                            187
# Alabama                                         187
# Reba Mcentire                                   187
# Chaka Khan                                      186
# Dean Martin                                     186
# Hank Williams Jr.                               185
# Neil Young                                      185
# Indigo Girls                                    184
# Nazareth                                        184
# America                                         184
# Cliff Richard                                   184
# Johnny Cash                                     183
# Kiss                                            183
# ...

# %% [markdown]
# ## Unique artists

# %%
unique_artists = df.artist.unique()
print "There are", len(unique_artists), "unique artists"
unique_artists
# Out:
# There are 643 unique artists
# array(['ABBA', 'Ace Of Base', 'Adam Sandler', 'Adele', 'Aerosmith',
#        'Air Supply', 'Aiza Seguerra', 'Alabama', 'Alan Parsons Project',
#        'Aled Jones', 'Alice Cooper', 'Alice In Chains', 'Alison Krauss',
#        'Allman Brothers Band', 'Alphaville', 'America', 'Amy Grant',
#        'Andrea Bocelli', 'Andy Williams', 'Annie', 'Ariana Grande',
#        'Ariel Rivera', 'Arlo Guthrie', 'Arrogant Worms', 'Avril Lavigne',
#        'Backstreet Boys', 'Barbie', 'Barbra Streisand', 'Beach Boys',
#        'The Beatles', 'Beautiful South', 'Beauty And The Beast',
#        'Bee Gees', 'Bette Midler', 'Bill Withers', 'Billie Holiday',
#        'Billy Joel', 'Bing Crosby', 'Black Sabbath', 'Blur', 'Bob Dylan',
#        'Bob Marley', 'Bob Rivers', 'Bob Seger', 'Bon Jovi', 'Boney M.',
#        'Bonnie Raitt', 'Bosson', 'Bread', 'Britney Spears',
#        'Bruce Springsteen', 'Bruno Mars', 'Bryan White', 'Cake',
# ...

# %% [markdown]
# ## Songs that name occur more than once

# %%
# Songs that appear more than once
song_occurrences = df.groupby('song')
song_occurrences_over_1 = song_occurrences.filter(lambda x: len(x) > 1)
duplicate_song_groups = song_occurrences_over_1.groupby('song').groups
duplicate_song_groups
# Out:
# {'Black Mountain Blues': Int64Index([14006, 37472], dtype='int64'),
#  'Borderline': Int64Index([3399, 23155, 23559, 26096, 27163, 38573, 42503, 51403, 53024], dtype='int64'),
#  'Sugar': Int64Index([32660, 40174, 41438, 43160, 52657, 57448], dtype='int64'),
#  'Horse Called Music': Int64Index([17003, 56593], dtype='int64'),
#  'After The Goldrush': Int64Index([4263, 13794], dtype='int64'),
#  'Foundation': Int64Index([21868, 51907], dtype='int64'),
#  'Umbrella': Int64Index([19161, 54012], dtype='int64'),
#  "God's Top Ten": Int64Index([2768, 37057], dtype='int64'),
#  "It's A Man's World": Int64Index([27335, 34513, 36420], dtype='int64'),
#  'Rattlesnake Shake': Int64Index([188, 6200], dtype='int64'),
#  'Have A Nice Day': Int64Index([1752, 26461, 50004], dtype='int64'),
#  'Nine Pound Hammer': Int64Index([9609, 53799], dtype='int64'),
#  "I'm With You": Int64Index([1768, 24405], dtype='int64'),
#  'Mad Love': Int64Index([1986, 11656, 18536], dtype='int64'),
# ...
